# %%
import pandas as pd

# %%
df_operadoras = pd.read_csv('Relatorio_cadop.csv', sep=';') # adicionado o sep=';'
df_operadoras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Registro_ANS               1106 non-null   int64
#  1   CNPJ                       1106 non-null   int64
#  2   Razao_Social               1106 non-null   object
#  3   Nome_Fantasia              951 non-null    object
#  4   Modalidade                 1106 non-null   object
#  5   Logradouro                 1106 non-null   object
#  6   Numero                     1106 non-null   object
#  7   Complemento                546 non-null    object
#  8   Bairro                     1106 non-null   object
#  9   Cidade                     1106 non-null   object
#  10  UF                         1106 non-null   object
#  11  CEP                        1106 non-null   int64
#  12  DDD                        997 non-null    float64
#  13  Telefone                   999 non-null    float64
#  14  Fax                        509 non-null    float64
#  15  Endereco_eletronico        1104 non-null   object
#  16  Representante              1106 non-null   object
#  17  Cargo_Representante        1106 non-null   object
#  18  Regiao_de_Comercializacao  978 non-null    float64
#  19  Data_Registro_ANS          1106 non-null   object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 172.9+ KB

# %%
# retirar nan
df_operadoras = df_operadoras.fillna('')
df_operadoras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Registro_ANS               1106 non-null   int64
#  1   CNPJ                       1106 non-null   int64
#  2   Razao_Social               1106 non-null   object
#  3   Nome_Fantasia              1106 non-null   object
#  4   Modalidade                 1106 non-null   object
#  5   Logradouro                 1106 non-null   object
#  6   Numero                     1106 non-null   object
#  7   Complemento                1106 non-null   object
#  8   Bairro                     1106 non-null   object
#  9   Cidade                     1106 non-null   object
#  10  UF                         1106 non-null   object
#  11  CEP                        1106 non-null   int64
#  12  DDD                        1106 non-null   object
#  13  Telefone                   1106 non-null   object
#  14  Fax                        1106 non-null   object
#  15  Endereco_eletronico        1106 non-null   object
#  16  Representante              1106 non-null   object
#  17  Cargo_Representante        1106 non-null   object
#  18  Regiao_de_Comercializacao  1106 non-null   object
#  19  Data_Registro_ANS          1106 non-null   object
# dtypes: int64(3), object(17)
# memory usage: 172.9+ KB

# %%
def busca_textual(texto_busca: str):
    registros = []
    for _, op in df_operadoras.iterrows():
        if (texto_busca.lower() in str(op['Razao_Social']).lower() or 
            texto_busca.lower() in str(op['Nome_Fantasia']).lower() or 
            texto_busca.lower() in str(op['Modalidade']).lower() or 
            texto_busca.lower() in str(op['Logradouro']).lower() or 
            texto_busca.lower() in str(op['Complemento']).lower() or
            texto_busca.lower() in str(op['Bairro']).lower() or 
            texto_busca.lower() in str(op['Cidade']).lower() or 
            texto_busca.lower() in str(op['UF']).lower() or 
            texto_busca.lower() in str(op['Endereco_eletronico']).lower() or 
            texto_busca.lower() in str(op['Representante']).lower() or 
            texto_busca.lower() in str(op['Cargo_Representante']).lower()):
            registros.append(op.to_dict())
    return registros

print(busca_textual('SP'))
# Out:
# [{'Registro_ANS': 421545, 'CNPJ': 22869997000153, 'Razao_Social': '2B ODONTOLOGIA OPERADORA DE PLANOS ODONTOLÓGICOS LTDA', 'Nome_Fantasia': '', 'Modalidade': 'Odontologia de Grupo', 'Logradouro': 'RUA CATÃO', 'Numero': '128', 'Complemento': 'SALA 126', 'Bairro': 'VILA ROMANA', 'Cidade': 'São Paulo', 'UF': 'SP', 'CEP': 5049000, 'DDD': 11.0, 'Telefone': 34415852.0, 'Fax': '', 'Endereco_eletronico': 'labmarisol@gmail.com', 'Representante': 'MARISOL BECHELLI', 'Cargo_Representante': 'SÓCIO ADMINISTRADORA', 'Regiao_de_Comercializacao': 4.0, 'Data_Registro_ANS': '2019-06-13'}, {'Registro_ANS': 421421, 'CNPJ': 27452545000195, 'Razao_Social': '2CARE OPERADORA DE SAÚDE LTDA.', 'Nome_Fantasia': '', 'Modalidade': 'Medicina de Grupo', 'Logradouro': 'RUA: BERNARDINO DE CAMPOS', 'Numero': '230', 'Complemento': '1º ANDAR', 'Bairro': 'CENTRO', 'Cidade': 'Campinas', 'UF': 'SP', 'CEP': 13010151, 'DDD': 19.0, 'Telefone': 37901224.0, 'Fax': '', 'Endereco_eletronico': 'ans.plano@hospitalcare.com.br', 'Representante': 'RODRIGO PINHO RIBEIRO', 'Cargo_Representante': 'REPRESENTANTE', 'Regiao_de_Comercializacao': 5.0, 'Data_Registro_ANS': '2018-10-09'}, {'Registro_ANS': 422908, 'CNPJ': 41788751000100, 'Razao_Social': '3S ADMINISTRADORA DE BENEFICIOS LTDA', 'Nome_Fantasia': '3S ADMINISTRADORA DE BENEFICIOS', 'Modalidade': 'Administradora de Benefícios', 'Logradouro': 'RUA ITÁLIA', 'Numero': '33', 'Complemento': 'SALA 6', 'Bairro': 'JARDIM BONFIGLIOLI', 'Cidade': 'Jundiaí', 'UF': 'SP', 'CEP': 13207280, 'DDD': 11.0, 'Telefone': 42263247.0, 'Fax': '', 'Endereco_eletronico': 'pietrorocchi37@gmail.com', 'Representante': 'ANAMELIA MONTEIRO GUERRA ROCCHI', 'Cargo_Representante': 'SÓCIO ADMINISTRADOR', 'Regiao_de_Comercializacao': 6.0, 'Data_Registro_ANS': '2021-07-12'}, {'Registro_ANS': 418030, 'CNPJ': 13138885000131, 'Razao_Social': 'A.P.S. ADMINISTRADORA DE BENEFÍCOS LTDA.', 'Nome_Fantasia': 'A.P.S. SAÚDE.', 'Modalidade': 'Administradora de Benefícios', 'Logradouro': 'RUA VOLUNTÁRIOS DA PÁTRIA', 'Numero': '2525', 'Complemento': 'CONJUNTO 143 - SALA 01', 'Bairro': 'SANTANA', 'Cidade': 'São Paulo', 'UF': 'SP', 'CEP': 2401000, 'DDD': 11.0, 'Telefone': 45223468.0, 'Fax': '', 'Endereco_eletronico': 'diretoria@apssaude.com.br', 'Representante': 'PERCÍVEL GAETA', 'Cargo_Representante': 'SóCIO-ADMINISTRADOR E REPRESEN', 'Regiao_de_Comercializacao': 4.0, 'Data_Registro_ANS': '2011-05-05'}, {'Registro_ANS': 424242, 'CNPJ': 56298884000167, 'Razao_Social': 'ABRANGE ADMINISTRADORA DE BENEFICIOS LTDA.', 'Nome_Fantasia': 'ABRANGE SAÚDE', 'Modalidade': 'Administradora de Benefícios', 'Logradouro': 'RUA CEL. JOSÉ EUSEBIO', 'Numero': '95.0', 'Complemento': 'SALA 13', 'Bairro': 'HIGIENOPOLIS', 'Cidade': 'São Paulo', 'UF': 'SP', 'CEP': 1239030, 'DDD': 11.0, 'Telefone': 920554400.0, 'Fax': '', 'Endereco_eletronico': 'dayanasantos@abrangesaude.com.br', 'Representante': 'DAYANA DOS SANTOSDE BRITO FLORÊNCIO', 'Cargo_Representante': 'ADMINISTRADORA', 'Regiao_de_Comercializacao': '', 'Data_Registro_ANS': '2025-01-06'}, {'Registro_ANS': 421553, 'CNPJ': 28315826000169, 'Razao_Social': 'ADM LIFE - ADMINISTRADORA DE BENEFÍCIOS LTDA.', 'Nome_Fantasia': 'ADM LIFE', 'Modalidade': 'Administradora de Benefícios', 'Logradouro': 'AVENIDA PEDROSO DE MORAIS', 'Numero': '272', 'Complemento': 'CJ 96', 'Bairro': 'PINHEIROS', 'Cidade': 'São Paulo', 'UF': 'SP', 'CEP': 5420000, 'DDD': 11.0, 'Telefone': 99475503.0, 'Fax': '', 'Endereco_eletronico': 'cristiane@admlife.com.br', 'Representante': 'NELITO JÚNIOR DE ALMEIDA SILVA', 'Cargo_Representante': 'Sócio Administrador', 'Regiao_de_Comercializacao': 4.0, 'Data_Registro_ANS': '2019-01-09'}, {'Registro_ANS': 416932, 'CNPJ': 7867825000157, 'Razao_Social': 'ADMSERV BENEFÍCIOS E SERVIÇOS LTDA', 'Nome_Fantasia': 'GÉIA ADMINISTRADORA DE BENEFICIOS', 'Modalidade': 'Administradora de Benefícios', 'Logradouro': 'Avenida Valdemar Ferreira', 'Numero': '463', 'Complemento': '', 'Bairro': 'Butantã', 'Cidade': 'São Paulo', 'UF': 'SP', 'CEP': 5501000, 'DDD': 11.0, 'Te ...
